# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The above screenshots are taken from the results in the files in the same directory.

# %% [markdown]
# From the classification reports of the 4 models, EfficientNetB0 is the best performing one and has the highest accuracy, followed by ResNet101, ResNet50 and finally VGG16 which was the worst performing model.
